# %% [markdown]
# ## How to Document Your Notebook
#
# Markdown cells are perfect for adding explanations, descriptions, and structural information to your notebook. Here's a quick guide on common markdown elements:
#
# *   **Headings**: Use `#` for main titles, `##` for subtitles, `###` for sub-subtitles, and so on. (e.g., `# My Title`, `## Section 1`).
# *   **Bold text**: Enclose text with double asterisks (e.g., `**important**`).
# *   **Italic text**: Enclose text with single asterisks (e.g., `*emphasized*`).
# *   **Lists**: Use hyphens (`-`), asterisks (`*`), or plus signs (`+`) for unordered lists, and numbers followed by a period (`1.`) for ordered lists.
#     *   Example unordered item
#     *   Another item
#     1.  Example ordered item
#     2.  Another item
# *   **Code blocks**: Enclose inline code with backticks (e.g., `print('Hello')`). For multi-line code blocks, use triple backticks and specify the language:
#
#     ```python
#     # Your code here
#     def my_function():
#         pass
#     ```
# *   **Links**: `[Link Text](URL)`
# *   **Horizontal Rule**: Three or more hyphens, asterisks, or underscores (e.g., `---`).
#
# Feel free to add more markdown cells throughout your notebook to explain your code, results, or thought process!

# %% [markdown]
# ## Notebook Documentation: Python Warmup
#
# This notebook serves as a foundational guide to essential Python concepts for data professionals. It is structured into several key sections, each focusing on a fundamental building block of Python programming.
#
# ### Covered Topics:
#
# 1.  **Variables and Data Types**: Introduces core Python data types such as integers (`int`), floating-point numbers (`float`), strings (`str`), booleans (`bool`), and lists (`list`). It provides examples and exercises to help users understand how to declare and manipulate these types.
# 2.  **Dictionaries**: Explores dictionaries as key-value pair collections, drawing parallels to database tables. Examples demonstrate how to create, access, and modify dictionary elements.
# 3.  **Functions**: Explains the importance of functions for code reusability and modularity. It covers defining functions, passing arguments, and returning values, including examples of functions with single and multiple return values. TODO exercises encourage users to write their own functions.
# 4.  **Loops**: Demonstrates the use of `for` loops for iterating over collections. Examples include basic iteration, using `enumerate` to get both index and value, and combining loops with conditional statements (`if`). TODO exercises challenge users to apply looping concepts to solve problems.
# 5.  **Putting It All Together**: A final exercise that combines variables, functions, and loops to solve a more complex data task, reinforcing the integrated application of learned concepts.

# %% [markdown]
# # Python Warmup -- Module 2, Class 1
#
# This notebook covers the Python fundamentals you need for data work:
# - Variables and data types
# - Functions
# - Loops
#
# Each section has examples first, then TODO exercises for you to complete.

# %% [markdown]
# ---
# ## 1. Variables and Data Types
#
# Python has four core data types you will use constantly:
# - **int** -- whole numbers (subscriber count, age)
# - **float** -- decimal numbers (bill amount, accuracy)
# - **str** -- text (customer name, region)
# - **bool** -- True or False (is_active, payment_on_time)
# - **list** -- ordered collection (monthly bills, feature names)

# %%
'''# --- EXAMPLES ---

# Integers
subscriber_count = 10_000_000
age = 25

# Floats
monthly_bill = 89_500.50
accuracy = 0.95

# Strings
customer_name = "Abdullayev Jasur"
region = "Tashkent"

# Booleans
is_active = True
payment_on_time = False

# Lists
monthly_bills = [85000, 92000, 78000, 95000, 88000]
regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana"]

# Check types
print(f"subscriber_count: {subscriber_count} (type: {type(subscriber_count).__name__})")
print(f"monthly_bill:     {monthly_bill} (type: {type(monthly_bill).__name__})")
print(f"customer_name:    {customer_name} (type: {type(customer_name).__name__})")
print(f"is_active:        {is_active} (type: {type(is_active).__name__})")
print(f"monthly_bills:    {monthly_bills} (type: {type(monthly_bills).__name__})")'''
# Out:
# '# --- EXAMPLES ---\n\n# Integers\nsubscriber_count = 10_000_000\nage = 25\n\n# Floats\nmonthly_bill = 89_500.50\naccuracy = 0.95\n\n# Strings\ncustomer_name = "Abdullayev Jasur"\nregion = "Tashkent"\n\n# Booleans\nis_active = True\npayment_on_time = False\n\n# Lists\nmonthly_bills = [85000, 92000, 78000, 95000, 88000]\nregions = ["Tashkent", "Samarkand", "Bukhara", "Fergana"]\n\n# Check types\nprint(f"subscriber_count: {subscriber_count} (type: {type(subscriber_count).__name__})")\nprint(f"monthly_bill:     {monthly_bill} (type: {type(monthly_bill).__name__})")\nprint(f"customer_name:    {customer_name} (type: {type(customer_name).__name__})")\nprint(f"is_active:        {is_active} (type: {type(is_active).__name__})")\nprint(f"monthly_bills:    {monthly_bills} (type: {type(monthly_bills).__name__})")'

# %%
'''# --- List operations ---

# Access by index (0-based)
print(f"First bill: {monthly_bills[0]}")
print(f"Last bill:  {monthly_bills[-1]}")

# Slicing
print(f"First 3 bills: {monthly_bills[:3]}")

# Length
print(f"Number of bills: {len(monthly_bills)}")

# Append
monthly_bills.append(91000)
print(f"After append: {monthly_bills}")'''
# Out:
# '# --- List operations ---\n\n# Access by index (0-based)\nprint(f"First bill: {monthly_bills[0]}")\nprint(f"Last bill:  {monthly_bills[-1]}")\n\n# Slicing\nprint(f"First 3 bills: {monthly_bills[:3]}")\n\n# Length\nprint(f"Number of bills: {len(monthly_bills)}")\n\n# Append\nmonthly_bills.append(91000)\nprint(f"After append: {monthly_bills}")'

# %%
'''# --- TODO: Variables exercise ---
# Create variables for a telecom customer profile:

# TODO: Create an integer variable for the customer's age
customer_age = 30

# TODO: Create a float variable for their monthly data usage in GB
data_usage_gb = 45.7

# TODO: Create a string variable for their city
city = "Tashkent"

# TODO: Create a boolean for whether they have a contract (vs prepaid)
has_contract = True

# TODO: Create a list of their last 6 monthly bills (make up reasonable numbers in soum)
bills = [75000, 82000, 78000, 90000, 85000, 88000]

# TODO: Print all variables with their types (follow the example pattern above)
print(f"customer_age: {customer_age} (type: {type(customer_age).__name__})")
print(f"data_usage_gb: {data_usage_gb} (type: {type(data_usage_gb).__name__})")
print(f"city: {city} (type: {type(city).__name__})")
print(f"has_contract: {has_contract} (type: {type(has_contract).__name__})")
print(f"bills: {bills} (type: {type(bills).__name__})")'''
# Out:
# '# --- TODO: Variables exercise ---\n# Create variables for a telecom customer profile:\n\n# TODO: Create an integer variable for the customer\'s age\ncustomer_age = 30\n\n# TODO: Create a float variable for their monthly data usage in GB\ndata_usage_gb = 45.7\n\n# TODO: Create a string variable for their city\ncity = "Tashkent"\n\n# TODO: Create a boolean for whether they have a contract (vs prepaid)\nhas_contract = True\n\n# TODO: Create a list of their last 6 monthly bills (make up reasonable numbers in soum)\nbills = [75000, 82000, 78000, 90000, 85000, 88000]\n\n# TODO: Print all variables with their types (follow the example pattern above)\nprint(f"customer_age: {customer_age} (type: {type(customer_age).__name__})")\nprint(f"data_usage_gb: {data_usage_gb} (type: {type(data_usage_gb).__name__})")\nprint(f"city: {city} (type: {type(city).__name__})")\nprint(f"has_contract: {has_contract} (type: {type(has_contract).__name__})")\nprint(f"bills: {bills} (type: {type(bills).__name__})")'

# %% [markdown]
# ---
# ## 2. Dictionaries
#
# A dictionary stores key-value pairs. Think of it as a single row in a database table -- keys are column names, values are the data.

# %%
'''# --- EXAMPLE ---

customer = {
    "id": "UZT-001234",
    "name": "Karimov Sherzod",
    "region": "Tashkent",
    "monthly_spend": 125000,
    "is_active": True,
    "plan": "Premium"
}

# Access values by key
print(f"Customer: {customer['name']}")
print(f"Region:   {customer['region']}")
print(f"Spend:    {customer['monthly_spend']} soum")

# Add a new key
customer["tenure_months"] = 24
print(f"\nFull record: {customer}")'''
# Out:
# '# --- EXAMPLE ---\n\ncustomer = {\n    "id": "UZT-001234",\n    "name": "Karimov Sherzod",\n    "region": "Tashkent",\n    "monthly_spend": 125000,\n    "is_active": True,\n    "plan": "Premium"\n}\n\n# Access values by key\nprint(f"Customer: {customer[\'name\']}")\nprint(f"Region:   {customer[\'region\']}")\nprint(f"Spend:    {customer[\'monthly_spend\']} soum")\n\n# Add a new key\ncustomer["tenure_months"] = 24\nprint(f"\nFull record: {customer}")'

# %%
'''# --- TODO: Dictionary exercise ---
# Create a dictionary representing a product from an e-commerce store
# Include at least 5 keys: name, category, price, quantity_sold, rating

# TODO: Create the product dictionary
product = None

# TODO: Print the product name and price

# TODO: Add a new key "discount" with a value between 0 and 1

# TODO: Print all keys using product.keys()'''
# Out:
# '# --- TODO: Dictionary exercise ---\n# Create a dictionary representing a product from an e-commerce store\n# Include at least 5 keys: name, category, price, quantity_sold, rating\n\n# TODO: Create the product dictionary\nproduct = None\n\n# TODO: Print the product name and price\n\n# TODO: Add a new key "discount" with a value between 0 and 1\n\n# TODO: Print all keys using product.keys()'

# %% [markdown]
# ---
# ## 3. Functions
#
# Functions take inputs, perform an operation, and return an output. They let you write reusable, modular code.
#
# In ML, every step of a pipeline is typically a function: load_data(), clean_data(), train_model(), evaluate().

# %%
'''# --- EXAMPLE: calculate_average ---

def calculate_average(numbers):
    """Calculate the average of a list of numbers."""
    total = sum(numbers)
    count = len(numbers)
    return total / count

bills = [85000, 92000, 78000, 95000, 88000, 91000]
avg_bill = calculate_average(bills)
print(f"Average monthly bill: {avg_bill:,.0f} soum")'''
# Out:
# '# --- EXAMPLE: calculate_average ---\n\ndef calculate_average(numbers):\n    """Calculate the average of a list of numbers."""\n    total = sum(numbers)\n    count = len(numbers)\n    return total / count\n\nbills = [85000, 92000, 78000, 95000, 88000, 91000]\navg_bill = calculate_average(bills)\nprint(f"Average monthly bill: {avg_bill:,.0f} soum")'

# %%
'''# --- EXAMPLE: function with multiple returns ---

def describe_bills(bills):
    """Return basic statistics for a list of bills."""
    avg = sum(bills) / len(bills)
    minimum = min(bills)
    maximum = max(bills)
    return avg, minimum, maximum

avg, low, high = describe_bills(bills)
print(f"Average: {avg:,.0f} | Min: {low:,.0f} | Max: {high:,.0f}")'''
# Out:
# '# --- EXAMPLE: function with multiple returns ---\n\ndef describe_bills(bills):\n    """Return basic statistics for a list of bills."""\n    avg = sum(bills) / len(bills)\n    minimum = min(bills)\n    maximum = max(bills)\n    return avg, minimum, maximum\n\navg, low, high = describe_bills(bills)\nprint(f"Average: {avg:,.0f} | Min: {low:,.0f} | Max: {high:,.0f}")'

# %%
'''# --- TODO: Write your own functions ---

# TODO 1: Write a function called `classify_customer` that takes monthly_spend as input
#         and returns:
#         - "premium" if spend > 150000
#         - "standard" if spend is between 50000 and 150000 (inclusive)
#         - "basic" if spend < 50000

def classify_customer(monthly_spend):
    # TODO: implement this function
    pass

# Test your function:
# print(classify_customer(200000))  # should print "premium"
# print(classify_customer(75000))   # should print "standard"
# print(classify_customer(30000))   # should print "basic"'''
# Out:
# '# --- TODO: Write your own functions ---\n\n# TODO 1: Write a function called `classify_customer` that takes monthly_spend as input\n#         and returns:\n#         - "premium" if spend > 150000\n#         - "standard" if spend is between 50000 and 150000 (inclusive)\n#         - "basic" if spend < 50000\n\ndef classify_customer(monthly_spend):\n    # TODO: implement this function\n    pass\n\n# Test your function:\n# print(classify_customer(200000))  # should print "premium"\n# print(classify_customer(75000))   # should print "standard"\n# print(classify_customer(30000))   # should print "basic"'

# %%
'''# TODO 2: Write a function called `calculate_churn_rate` that takes two arguments:
#         - total_customers (int)
#         - churned_customers (int)
#         Returns the churn rate as a percentage (float).

def calculate_churn_rate(total_customers, churned_customers):
    # TODO: implement this function
    pass

# Test:
# print(calculate_churn_rate(10000, 350))  # should print 3.5'''
# Out:
# '# TODO 2: Write a function called `calculate_churn_rate` that takes two arguments:\n#         - total_customers (int)\n#         - churned_customers (int)\n#         Returns the churn rate as a percentage (float).\n\ndef calculate_churn_rate(total_customers, churned_customers):\n    # TODO: implement this function\n    pass\n\n# Test:\n# print(calculate_churn_rate(10000, 350))  # should print 3.5'

# %% [markdown]
# ---
# ## 4. Loops
#
# Loops let you repeat an operation across a collection. In data work, you iterate over rows, columns, files, or parameter values constantly.

# %%
# '''# --- EXAMPLE: basic for loop ---

regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana", "Namangan"]

for region in regions:
    print(f"Processing data for: {region}")'''
# Out:
# '# --- EXAMPLE: basic for loop ---\n\nregions = ["Tashkent", "Samarkand", "Bukhara", "Fergana", "Namangan"]\n\nfor region in regions:\n    print(f"Processing data for: {region}")'

# %%
--- EXAMPLE: enumerate (index + value) ---
# enumerate gives you both the position and the value

monthly_bills = [85000, 92000, 78000, 95000, 88000, 91000]

for i, bill in enumerate(monthly_bills):
    print(f"Month {i + 1}: {bill:,} soum")
# Out:
# Month 1: 85,000 soum
# Month 2: 92,000 soum
# Month 3: 78,000 soum
# Month 4: 95,000 soum
# Month 5: 88,000 soum
# Month 6: 91,000 soum

# %%
# --- EXAMPLE: loop with conditional ---

customers = [
    {"name": "Alisher", "spend": 200000},
    {"name": "Dilnoza", "spend": 45000},
    {"name": "Bobur",   "spend": 120000},
    {"name": "Malika",  "spend": 35000},
    {"name": "Rustam",  "spend": 180000},
]

print("High-value customers (spend > 100,000):")
for c in customers:
    if c["spend"] > 100000:
        print(f"  {c['name']}: {c['spend']:,} soum")
# Out:
# High-value customers (spend > 100,000):
#   Alisher: 200,000 soum
#   Bobur: 120,000 soum
#   Rustam: 180,000 soum

# %%
# --- TODO: Loop exercises ---

# TODO 1: Using the `customers` list above, loop through and classify each customer
#         using your classify_customer function from Section 3.
#         Print: "Name: <name>, Tier: <tier>"

# Your code here:

# %%
# TODO 2: Given the list of scores below, use enumerate to print each score
#         with its rank (starting from 1), and mark scores above 90 with " -- HIGH"
#
# Expected output:
#   Rank 1: 72
#   Rank 2: 95 -- HIGH
#   Rank 3: 88
#   ...

scores = [72, 95, 88, 61, 93, 77, 85, 91, 68, 99]

# Your code here:

# %%
# TODO 3: Write a loop that computes the total and average of the scores list.
#         Do NOT use sum() or len() -- compute manually with a loop.
#         Print: "Total: <total>, Average: <average>"

# Your code here:

# %% [markdown]
# ---
# ## 5. Putting It All Together
#
# Combine variables, functions, and loops to solve a mini data task.

# %%
# --- TODO: Final exercise ---
#
# You have a dataset of 8 customers (list of dictionaries).
# Write code that:
# 1. Loops through each customer
# 2. Classifies them into tiers (use classify_customer or write inline logic)
# 3. Counts how many customers are in each tier
# 4. Prints a summary: "Premium: X, Standard: Y, Basic: Z"

customers_data = [
    {"id": 1, "name": "Anvar",   "monthly_spend": 210000},
    {"id": 2, "name": "Nilufar", "monthly_spend": 55000},
    {"id": 3, "name": "Sardor",  "monthly_spend": 180000},
    {"id": 4, "name": "Gulnora", "monthly_spend": 32000},
    {"id": 5, "name": "Timur",   "monthly_spend": 95000},
    {"id": 6, "name": "Madina",  "monthly_spend": 160000},
    {"id": 7, "name": "Otabek",  "monthly_spend": 47000},
    {"id": 8, "name": "Zarina",  "monthly_spend": 125000},
]

# Your code here:

# %%
# Out:
# 'text'

# %% [markdown]
# # Task
# Complete the "Variables exercise" in cell `zOg5vtm0u-vB` by defining variables for a telecom customer profile (`customer_age`, `data_usage_gb`, `city`, `has_contract`, `bills`) with example values and appropriate comments, then add print statements to display each variable's value and data type.

# %% [markdown]
# ## Define Customer Variables
#
# ### Subtask:
# In cell `zOg5vtm0u-vB`, replace the `pass` statements or initial `None` assignments with actual values for the `customer_age` (int), `data_usage_gb` (float), `city` (str), `has_contract` (bool), and `bills` (list) variables. Make up reasonable example values for a telecom customer.

# %% [markdown]
# # Task
# Complete the "Dictionary Exercise" in cell `PQ-ellvAu-vB` by creating a product dictionary with at least five keys (`name`, `category`, `price`, `quantity_sold`, `rating`), printing its name and price, adding a 'discount' key with a value between 0 and 1, and then printing all keys using `product.keys()`.

# %% [markdown]
# ## Complete Dictionary Exercise
#
# ### Subtask:
# Address the TODOs in cell PQ-ellvAu-vB. Create the product dictionary, print the specified details, and add the 'discount' key. Ensure the general explanation of dictionaries (creation, access, add/modify) is clear within the notebook, incorporating the previous explanations we've done.

# %% [markdown]
# # Task
# Complete the dictionary exercise in cell `PQ-ellvAu-vB` by creating a Python dictionary named `product` with keys `name` (string), `category` (string), `price` (float), `quantity_sold` (integer), and `rating` (float), and populate them with example e-commerce product values. Then, print the product's name and price using f-strings, add a new key `discount` with a float value between 0 and 1, and finally, print all keys of the `product` dictionary using the `.keys()` method.

# %% [markdown]
# ## Create Product Dictionary
#
# ### Subtask:
# In cell PQ-ellvAu-vB, create a Python dictionary named `product` with at least five keys: `name` (string), `category` (string), `price` (float), `quantity_sold` (integer), and `rating` (float). Populate these keys with example values relevant to an e-commerce product.
