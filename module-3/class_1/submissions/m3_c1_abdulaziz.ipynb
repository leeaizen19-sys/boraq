# %%
# === SETUP — run this first ===
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings; warnings.filterwarnings('ignore')

# importing the necessary libraries

url = 'https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv'
df = pd.read_csv(url)
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce').fillna(0)
print('Loaded:', df.shape)

# the data shape

# %%
df.isnull().sum()
# checking for null values

# %%
print('Duplicates:', df.duplicated().sum())
# printing the number of duplicate rows

# %%
df_test = df.copy()
df_test.loc[0:9, 'tenure'] = np.nan
print('Missing tenure now:', df_test['tenure'].isnull().sum())
# creating a test dataframe with missing values in the 'tenure' column

# %%
median_tenure = df_test['tenure'].median()
df_test['tenure'] = df_test['tenure'].fillna(median_tenure)
print('After fillna, missing:', df_test['tenure'].isnull().sum())
print('Median used:', median_tenure)
# filling missing values with the median

# %%
df['TotalCharges'] = df['TotalCharges'].fillna(0)
print('TotalCharges missing after fillna:', df['TotalCharges'].isnull().sum())
# filling missing values in 'TotalCharges' with 0

# %%
before = len(df)
df = df.drop_duplicates()
after = len(df)
print(f'Before: {before}, After: {after}, Dropped: {before - after}')
# comparing the length of the dataframe before and after dropping the duplicates

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].map({0: 'No', 1: 'Yes'})
df['SeniorCitizen'].value_counts()

# converting the 'SeniorCitizen' column to a categorical variable

# %%
df['gender'] = df['gender'].str.strip()
df['gender'].value_counts()
# removing the extra space before and after the string
